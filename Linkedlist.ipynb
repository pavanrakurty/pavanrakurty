# %% [markdown]
# <a href="https://colab.research.google.com/github/pavanrakurty/pavanrakurty/blob/main/Linkedlist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##Singly linkedlist

class SinglyNode:
  def __init__(self, val, next = None):
    self.val = val
    self.next = next

  def __str__(self):
    return str(self.val)

# %%
head = SinglyNode(1)
A = SinglyNode(2)
B = SinglyNode(3)
C = SinglyNode(4)

print(head)
# Out:
# 1

# %%
head.next = A
A.next = B
B.next = C

# %%
curr = head

while curr:
  print(curr)
  curr = curr.next
# Out:
# 1
# 2
# 3
# 4

# %%
def searchLinkedList(head, val):
  curr = head
  while curr:
    if curr.val == val:
      return True
    curr = curr.next
  return False

searchLinkedList(head, 5)
# Out:
# False

# %%
##Doubly LinkedList

class DoublyNode:
  def __init__(self, val, prev=None, next=None):
    self.val = val
    self.prev = prev
    self.next = next

  def __str__(self):
    print(str(self.val))

# %%
def display(head):
  curr = head
  elements = []
  while curr:
    elements.append(str(curr.val))
    curr = curr.next
  print(' <-> '.join(elements))

# %%
head = tail = DoublyNode(1)

display(head)
# Out:
# 1

# %%
def add_element_beginning(val, head, tail):
  new_node = DoublyNode(val,next=head)
  head.prev = new_node
  return new_node, tail

head, tail = add_element_beginning(0, head, tail)
display(head)
# Out:
# 0 <-> 1

# %%
def add_element_at_end(val, head, tail):
  new_node = DoublyNode(val, prev=tail)
  tail.next = new_node
  return head, new_node

head, tail = add_element_at_end(2, head, tail)
display(head)
# Out:
# 0 <-> 1 <-> 2
